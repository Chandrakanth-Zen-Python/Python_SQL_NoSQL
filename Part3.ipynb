# %%
# Importing Libraries

# pip - python installer packages

# %% [raw]
# PANDAS
#
# Documentation: https://pandas.pydata.org/docs/

# %%
import pandas as pd

# %%
data=pd.read_csv('sales_data_sample.csv',encoding='utf-8',encoding_errors="replace")

# %%
data
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# - Navigating Dataframe
# - Adding New Data To Dataframe
# - Columnwise Operations
# - Pivoting
# - Grouping
# - Joins
# - Export

# %%
# first 'n' rows

data.head(6)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
# 5  10/28/2003 0:00  Shipped       4        10     2003  ...
#
# ...

# %%
# last 5 rows

data.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
# index

# %%
data.loc[5]
# Out:
# ORDERNUMBER                        10168
# QUANTITYORDERED                       36
# PRICEEACH                          96.66
# ORDERLINENUMBER                        1
# SALES                            3479.76
# ORDERDATE                10/28/2003 0:00
# STATUS                           Shipped
# QTR_ID                                 4
# MONTH_ID                              10
# YEAR_ID                             2003
# PRODUCTLINE                  Motorcycles
# MSRP                                  95
# PRODUCTCODE                     S10_1678
# CUSTOMERNAME        Technics Stores Inc.
# PHONE                         6505556809
# ADDRESSLINE1           9408 Furth Circle
# ADDRESSLINE2                         NaN
# CITY                          Burlingame
# STATE                                 CA
# POSTALCODE                         94217
# COUNTRY                              USA
# TERRITORY                            NaN
# CONTACTLASTNAME                   Hirano
# ...

# %%
data.loc[10:20]
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# 12        10251               28     100.00                2  3188.64
# 13        10263               34     100.00                2  3676.76
# 14        10275               45      92.83                1  4177.35
# 15        10285               36     100.00                6  4099.68
# 16        10299               23     100.00                9  2597.39
# 17        10309               41     100.00                5  4394.38
# 18        10318               46      94.74                1  4358.04
# 19        10329               42     100.00                1  4396.14
# 20        10341               41     100.00                9  7737.93
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10   2/20/2004 0:00  Shipped       1         2     2004  ...
# ...

# %%
data.loc[data['ORDERNUMBER']==10275]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 14          10275               45      92.83                1  4177.35
# 68          10275               22     100.00                4  2904.44
# 94          10275               36     100.00                3  6901.92
# 791         10275               35      90.39                9  3163.65
# 818         10275               37      63.60                5  2353.20
# 1480        10275               21     100.00                2  2153.76
# 1526        10275               25      95.20               11  2380.00
# 1578        10275               30      79.98                6  2399.40
# 2010        10275               41      81.89               18  3357.49
# 2108        10275               27      62.31               10  1682.37
# 2184        10275               23      81.91                7  1883.93
# 2313        10275               28      63.97               12  1791.16
# ...

# %%
data.loc[(data['ORDERNUMBER']==10275)&(data["ORDERLINENUMBER"]==9)]
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 791        10275               35      90.39                9  3163.65
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 791  7/23/2004 0:00  Shipped       3         7     2004  ...
#
#                      ADDRESSLINE1  ADDRESSLINE2    CITY STATE POSTALCODE  \
# 791  67, rue des Cinquante Otages           NaN  Nantes   NaN      44000
#
#     COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 791  France      EMEA         Labrune           Janine   Medium
#
# [1 rows x 25 columns]

# %%
data.loc[(data['ORDERLINENUMBER']==5)|(data['ORDERLINENUMBER']==9)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               34      81.35                5  2765.90
# 6           10180               29      86.13                9  2497.77
# 16          10299               23     100.00                9  2597.39
# 17          10309               41     100.00                5  4394.38
# 20          10341               41     100.00                9  7737.93
# ...           ...              ...        ...              ...      ...
# 2800        10142               39      44.23                5  1724.97
# 2809        10248               23      65.52                9  1506.96
# 2815        10315               40      55.69                5  2227.60
# 2817        10337               42      97.16                5  4080.72
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# Datatypes

# %%
data.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
data['YEAR_ID']=data['YEAR_ID'].astype(str)

# %%
data.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID              object
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
# renaming the columns

data=data.rename(columns={"YEAR_ID":"YEAR","MONTH_ID":"MONTH","QTR_ID":"QTR"})

# %%
data.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR                   int64
# MONTH                 int64
# YEAR                 object
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
# Changing the existing data

# %%
data.loc[(data['ORDERNUMBER']==10121)&(data['ORDERLINENUMBER']==5),"QUANTITYORDERED"]=35

# %%
data.loc[(data['ORDERNUMBER']==10121)&(data['ORDERLINENUMBER']==5),"SALES"]=2765.90+81.35

# %%
data.loc[(data['ORDERLINENUMBER']==5)|(data['ORDERLINENUMBER']==9)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1           10121               35      81.35                5  2847.25
# 6           10180               29      86.13                9  2497.77
# 16          10299               23     100.00                9  2597.39
# 17          10309               41     100.00                5  4394.38
# 20          10341               41     100.00                9  7737.93
# ...           ...              ...        ...              ...      ...
# 2800        10142               39      44.23                5  1724.97
# 2809        10248               23      65.52                9  1506.96
# 2815        10315               40      55.69                5  2227.60
# 2817        10337               42      97.16                5  4080.72
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE     STATUS  QTR  MONTH  YEAR  ...  \
# ...

# %%
# Columnwise Operations

# %%
data=data.drop(columns=['SALES'])

# %%
data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'ORDERDATE', 'STATUS', 'QTR', 'MONTH', 'YEAR', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2',
#        'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE'],
#       dtype='object')

# %%
salesFig=[]

for id, row in data.iterrows():

    salesFig.append(row['QUANTITYORDERED']* row['PRICEEACH'])

# %%
data['SALES']=salesFig

# %%
data.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER        ORDERDATE  \
# 0        10107               30      95.70                2   2/24/2003 0:00
# 1        10121               35      81.35                5    5/7/2003 0:00
# 2        10134               41      94.74                2    7/1/2003 0:00
# 3        10145               45      83.26                6   8/25/2003 0:00
# 4        10159               49     100.00               14  10/10/2003 0:00
#
#     STATUS  QTR  MONTH  YEAR  PRODUCTLINE  ...  ADDRESSLINE2           CITY  \
# 0  Shipped    1      2  2003  Motorcycles  ...           NaN            NYC
# 1  Shipped    2      5  2003  Motorcycles  ...           NaN          Reims
# 2  Shipped    3      7  2003  Motorcycles  ...           NaN          Paris
# 3  Shipped    3      8  2003  Motorcycles  ...           NaN       Pasadena
# 4  Shipped    4     10  2003  Motorcycles  ...           NaN  San Francisco
#
# ...

# %%
data['SALES_COLUMNWISE']=data['QUANTITYORDERED']*data['PRICEEACH']

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER        ORDERDATE  \
# 0        10107               30      95.70                2   2/24/2003 0:00
# 1        10121               35      81.35                5    5/7/2003 0:00
# 2        10134               41      94.74                2    7/1/2003 0:00
# 3        10145               45      83.26                6   8/25/2003 0:00
# 4        10159               49     100.00               14  10/10/2003 0:00
#
#     STATUS  QTR  MONTH  YEAR  PRODUCTLINE  ...           CITY STATE  \
# 0  Shipped    1      2  2003  Motorcycles  ...            NYC    NY
# 1  Shipped    2      5  2003  Motorcycles  ...          Reims   NaN
# 2  Shipped    3      7  2003  Motorcycles  ...          Paris   NaN
# 3  Shipped    3      8  2003  Motorcycles  ...       Pasadena    CA
# 4  Shipped    4     10  2003  Motorcycles  ...  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  \
# ...

# %%
data["YEARMONTH"]=data['MONTH'].astype(str)+"-"+data['YEAR']

# %%
data['YEARMONTH']
# Out:
# 0        2-2003
# 1        5-2003
# 2        7-2003
# 3        8-2003
# 4       10-2003
#          ...
# 2818    12-2004
# 2819     1-2005
# 2820     3-2005
# 2821     3-2005
# 2822     5-2005
# Name: YEARMONTH, Length: 2823, dtype: object

# %%
# Pivoting

# %%
data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'ORDERDATE', 'STATUS', 'QTR', 'MONTH', 'YEAR', 'PRODUCTLINE', 'MSRP',
#        'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2',
#        'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY',
#        'CONTACTLASTNAME', 'CONTACTFIRSTNAME', 'DEALSIZE', 'SALES',
#        'SALES_COLUMNWISE', 'YEARMONTH'],
#       dtype='object')

# %%
product_qty_table=pd.pivot_table(data,values=["QUANTITYORDERED"],index=["PRODUCTCODE","QTR"],aggfunc=sum)
# Out:
# /tmp/ipykernel_39213/1446116367.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   product_qty_table=pd.pivot_table(data,values=["QUANTITYORDERED"],index=["QTR"],aggfunc=sum)

# %%
product_qty_table
# Out:
#      QUANTITYORDERED
# QTR
# 1              23485
# 2              20317
# 3              17118
# 4              38148

# %%
agg2=pd.pivot_table(data,values=["ORDERNUMBER"],
                                 index=["YEAR","QTR"],
                                 aggfunc=len)

# %%
agg2
# Out:
#           ORDERNUMBER
# YEAR QTR
# 2003 1            130
#      2            162
#      3            184
#      4            524
# 2004 1            233
#      2            223
#      3            319
#      4            570
# 2005 1            302
#      2            176

# %%
# GROUPING

# %%
qtrwise_data=data.groupby(by=["QTR"])

# %%
len(qtrwise_data)
# Out:
# 4

# %%
for qtr in qtrwise_data.groups:
# Out:
# 1
# 2
# 3
# 4

# %%
qtrwise_data.get_group(1)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 0           10107               30      95.70                2
# 9           10211               41     100.00               14
# 10          10223               37     100.00                1
# 22          10375               21      34.91               12
# 23          10388               42      76.36                4
# ...           ...              ...        ...              ...
# 2807        10222               36      63.34               18
# 2808        10232               24      49.69                3
# 2819        10373               29     100.00                1
# 2820        10386               43     100.00                4
# 2821        10397               34      62.24                1
#
#            ORDERDATE    STATUS  QTR  MONTH  YEAR  PRODUCTLINE  ...  \
# 0     2/24/2003 0:00   Shipped    1      2  2003  Motorcycles  ...
# 9     1/15/2004 0:00   Shipped    1      1  2004  Motorcycles  ...
# ...

# %%
grouped_data=data.groupby(by=["YEAR","QTR"])

# %%
len(grouped_data)
# Out:
# 10

# %%
for grp in grouped_data.groups:

    print(grp)

    dataGrp=grouped_data.get_group(grp)

    print(sum(dataGrp['QUANTITYORDERED']))
# Out:
# ('2003', 1)
# 4561
# ('2003', 2)
# 5660
# ('2003', 3)
# 6209
# ('2003', 4)
# 18183
# ('2004', 1)
# 8284
# ('2004', 2)
# 7666
# ('2004', 3)
# 10909
# ('2004', 4)
# 19965
# ('2005', 1)
# 10640
# ('2005', 2)
# 6991

# %%
import random

# %%
# Joins

# %%
marksDF=pd.DataFrame.from_dict(
    [
        {
            "student_id":"001",
            "maths":85,
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        },
        {
            "student_id":"002",
            "maths":random.randint(35,98),
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        },
        {
            "student_id":"003",
            "maths":random.randint(35,98),
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        },
        {
            "student_id":"004",
            "maths":random.randint(35,98),
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        },
        {
            "student_id":"005",
            "maths":random.randint(35,98),
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        },
        {
            "student_id":"006",
           "maths":random.randint(35,98),
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        },
        {
            "student_id":"007",
            "maths":random.randint(35,98),
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        },
        {
            "student_id":"111",
            "maths":random.randint(35,98),
            "physics":random.randint(35,98),
            "chemistry":random.randint(35,98),
            "biology":random.randint(35,98),
            'english':random.randint(35,98),
        }
    ], orient='columns'
)

# %%
marksDF
# Out:
#   student_id  maths  physics  chemistry  biology  english
# 0        001     85       61         35       94       78
# 1        002     41       47         68       63       69
# 2        003     63       57         65       62       62
# 3        004     50       43         81       68       88
# 4        005     58       58         38       64       48
# 5        006     35       61         37       50       74
# 6        007     90       50         55       77       63
# 7        111     58       95         77       77       82

# %%
students=pd.DataFrame.from_dict( 
    data=[
    {
        "student_id": "001",
        "name": "John Doe",
        "address": "123 Main Street",
        "father_name": "Michael Doe",
        "dob": "2002-05-15"
    },
    {
        "student_id": "002",
        "name": "Alice Smith",
        "address": "456 Elm Street",
        "father_name": "David Smith",
        "dob": "2003-08-21"
    },
    {
        "student_id": "003",
        "name": "Emily Johnson",
        "address": "789 Oak Street",
        "father_name": "Andrew Johnson",
        "dob": "2002-12-03"
    },
    {
        "student_id": "004",
        "name": "James Brown",
        "address": "567 Pine Street",
        "father_name": "William Brown",
        "dob": "2003-02-28"
    },
    {
        "student_id": "005",
        "name": "Sophia Wilson",
        "address": "890 Maple Street",
        "father_name": "Daniel Wilson",
        "dob": "2002-07-10"
    },
    {
        "student_id": "006",
        "name": "Olivia Garcia",
        "address": "234 Cedar Street",
        "father_name": "Ethan Garcia",
        "dob": "2003-01-19"
    },
    {
        "student_id": "007",
        "name": "William Martinez",
        "address": "876 Birch Street",
        "father_name": "Liam Martinez",
        "dob": "2002-10-05"
    },
    {
        "student_id": "008",
        "name": "Elijah Nguyen",
        "address": "543 Spruce Street",
        "father_name": "Mason Nguyen",
        "dob": "2003-04-30"
    },
    {
        "student_id": "009",
        "name": "Ava Robinson",
        "address": "987 Walnut Street",
        "father_name": "Benjamin Robinson",
        "dob": "2002-06-25"
    }
    ]
,orient='columns'
)

# %%
students
# Out:
#   student_id              name            address        father_name  \
# 0        001          John Doe    123 Main Street        Michael Doe
# 1        002       Alice Smith     456 Elm Street        David Smith
# 2        003     Emily Johnson     789 Oak Street     Andrew Johnson
# 3        004       James Brown    567 Pine Street      William Brown
# 4        005     Sophia Wilson   890 Maple Street      Daniel Wilson
# 5        006     Olivia Garcia   234 Cedar Street       Ethan Garcia
# 6        007  William Martinez   876 Birch Street      Liam Martinez
# 7        008     Elijah Nguyen  543 Spruce Street       Mason Nguyen
# 8        009      Ava Robinson  987 Walnut Street  Benjamin Robinson
#
#           dob
# 0  2002-05-15
# 1  2003-08-21
# 2  2002-12-03
# 3  2003-02-28
# 4  2002-07-10
# 5  2003-01-19
# 6  2002-10-05
# 7  2003-04-30
# 8  2002-06-25

# %%
# inner join

df_report_card=pd.merge(students,marksDF,how="inner")

# %%
df_report_card
# Out:
#   student_id              name           address     father_name         dob  \
# 0        001          John Doe   123 Main Street     Michael Doe  2002-05-15
# 1        002       Alice Smith    456 Elm Street     David Smith  2003-08-21
# 2        003     Emily Johnson    789 Oak Street  Andrew Johnson  2002-12-03
# 3        004       James Brown   567 Pine Street   William Brown  2003-02-28
# 4        005     Sophia Wilson  890 Maple Street   Daniel Wilson  2002-07-10
# 5        006     Olivia Garcia  234 Cedar Street    Ethan Garcia  2003-01-19
# 6        007  William Martinez  876 Birch Street   Liam Martinez  2002-10-05
#
#    maths  physics  chemistry  biology  english
# 0     85       61         35       94       78
# 1     41       47         68       63       69
# 2     63       57         65       62       62
# 3     50       43         81       68       88
# 4     58       58         38       64       48
# 5     35       61         37       50       74
# ...

# %%
df_report_card_left=pd.merge(students,marksDF,how="left")

# %%
df_report_card_left
# Out:
#   student_id              name            address        father_name  \
# 0        001          John Doe    123 Main Street        Michael Doe
# 1        002       Alice Smith     456 Elm Street        David Smith
# 2        003     Emily Johnson     789 Oak Street     Andrew Johnson
# 3        004       James Brown    567 Pine Street      William Brown
# 4        005     Sophia Wilson   890 Maple Street      Daniel Wilson
# 5        006     Olivia Garcia   234 Cedar Street       Ethan Garcia
# 6        007  William Martinez   876 Birch Street      Liam Martinez
# 7        008     Elijah Nguyen  543 Spruce Street       Mason Nguyen
# 8        009      Ava Robinson  987 Walnut Street  Benjamin Robinson
#
#           dob  maths  physics  chemistry  biology  english
# 0  2002-05-15   85.0     61.0       35.0     94.0     78.0
# 1  2003-08-21   41.0     47.0       68.0     63.0     69.0
# 2  2002-12-03   63.0     57.0       65.0     62.0     62.0
# ...

# %%
df_report_card_right=pd.merge(students,marksDF,how="right")

# %%
df_report_card_right
# Out:
#   student_id              name           address     father_name         dob  \
# 0        001          John Doe   123 Main Street     Michael Doe  2002-05-15
# 1        002       Alice Smith    456 Elm Street     David Smith  2003-08-21
# 2        003     Emily Johnson    789 Oak Street  Andrew Johnson  2002-12-03
# 3        004       James Brown   567 Pine Street   William Brown  2003-02-28
# 4        005     Sophia Wilson  890 Maple Street   Daniel Wilson  2002-07-10
# 5        006     Olivia Garcia  234 Cedar Street    Ethan Garcia  2003-01-19
# 6        007  William Martinez  876 Birch Street   Liam Martinez  2002-10-05
# 7        111               NaN               NaN             NaN         NaN
#
#    maths  physics  chemistry  biology  english
# 0     85       61         35       94       78
# 1     41       47         68       63       69
# 2     63       57         65       62       62
# 3     50       43         81       68       88
# ...

# %%
# Export

# %%
df_report_card_left.to_csv('marks_table.csv')

# %%
df_report_card_left
